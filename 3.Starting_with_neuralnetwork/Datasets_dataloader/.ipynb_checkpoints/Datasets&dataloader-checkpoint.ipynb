# %%
import torch 
from torchvision import datasets
from torchvision.transforms import ToTensor
from matplotlib import pyplot as plt

# %%
training_datsets = datasets.FashionMNIST (
    root = "data" ,
    download = True , 
    train = True , 
    transform = ToTensor()
)

test_datsets = datasets.FashionMNIST (
    root = "data" ,
    download = True , 
    train = False , 
    transform = ToTensor()
)

# %%
len(training_datsets)
# Out:
# 60000

# %%
len(test_datsets)
# Out:
# 10000

# %%
image , label = training_datsets[0]

# %%
label
# Out:
# 9

# %%
image.squeeze().shape
# Out:
# torch.Size([28, 28])

# %%
labels_map = {
    0: "T-Shirt",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle Boot",
}

labels_map[label]
# Out:
# 'Shirt'

# %%
plt.imshow(image.squeeze() , cmap="gray")
plt.show()

# %%
figure = plt.figure(figsize=(8, 8))
cols, rows = 3, 3
for i in range(1, cols * rows + 1):
    sample_idx = torch.randint(len(training_datsets), size=(1,)).item()
    img, label = training_datsets[sample_idx]
    figure.add_subplot(rows, cols, i)
    plt.title(labels_map[label])
    plt.axis("off")
    plt.imshow(img.squeeze(), cmap="gray")
plt.show()

# %% [markdown]
# ## 2. DataLoaders

# %%
from torch.utils.data import DataLoader 

train_dataloader = DataLoader( training_datsets , batch_size=64 , shuffle=True )
test_dataloader = DataLoader( test_datsets , batch_size=64 , shuffle=True )

# %%
for images , labels in train_dataloader :
    print(images.shape)
    break
# Out:
# torch.Size([64, 1, 28, 28])

# %%
data = iter(train_dataloader)
image , labels = next(data)

# %%
image.squeeze().shape
# Out:
# torch.Size([64, 28, 28])

# %%
img = image[3].squeeze()
label = labels[3]

# %%
label.item()
# Out:
# 6

# %%
labels_map[label.item()]
# Out:
# 'Shirt'

# %%
plt.imshow(img, cmap="gray")
plt.show()
